# %%
#!pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading https://files.pythonhosted.org/packages/18/7f/c836c44ab30074a8486e30f8ea6adc8e6ac02332851ab6cc069e2ac35b84/opencv_python-3.4.3.18-cp36-cp36m-manylinux1_x86_64.whl (25.0MB)
#     100% |████████████████████████████████| 25.0MB 2.0MB/s
# Requirement already satisfied: numpy>=1.11.3 in /home/master/anaconda3/lib/python3.6/site-packages (from opencv-python) (1.14.3)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-3.4.3.18

# %%
import pandas as pd
import numpy as np
from skimage import io
from skimage.transform import rotate
import cv2
import os
import time

# %%
resized_train_path = '../../data/diabetic-retinopathy/train-resized-256/'

# %%
def rotate_images(file_path, degrees_of_rotation, lst_imgs):
    '''
    Rotates image based on a specified amount of degrees

    INPUT
        file_path: file path to the folder containing images.
        degrees_of_rotation: Integer, specifying degrees to rotate the
        image. Set number from 1 to 360.
        lst_imgs: list of image strings.

    OUTPUT
        Images rotated by the degrees of rotation specififed.
    '''

    for l in lst_imgs:
        img = io.imread(file_path + str(l) + '.jpeg')
        img = rotate(img, degrees_of_rotation)
        io.imsave(file_path + str(l) + '_' + str(degrees_of_rotation) + '.jpeg', img)


def mirror_images(file_path, mirror_direction, lst_imgs):
    '''
    Mirrors image left or right, based on criteria specified.

    INPUT
        file_path: file path to the folder containing images.
        mirror_direction: criteria for mirroring left or right.
        lst_imgs: list of image strings.

    OUTPUT
        Images mirrored left or right.
    '''

    for l in lst_imgs:
        img = cv2.imread(file_path + str(l) + '.jpeg')
        img = cv2.flip(img, 1)
        cv2.imwrite(file_path + str(l) + '_mir' + '.jpeg', img)

# %%
start_time = time.time()
trainLabels = pd.read_csv("trainLabels_master.csv")

trainLabels['image'] = trainLabels['image'].str.rstrip('.jpeg')
trainLabels_no_DR = trainLabels[trainLabels['level'] == 0]
trainLabels_DR = trainLabels[trainLabels['level'] >= 1]

lst_imgs_no_DR = [i for i in trainLabels_no_DR['image']]
lst_imgs_DR = [i for i in trainLabels_DR['image']]

# lst_sample = [i for i in os.listdir('../data/sample/') if i != '.DS_Store']
# lst_sample = [str(l.strip('.jpeg')) for l in lst_sample]


# Mirror Images with no DR one time
print("Mirroring Non-DR Images")
mirror_images(resized_train_path, 1, lst_imgs_no_DR)


# Rotate all images that have any level of DR
print("Rotating 90 Degrees")
rotate_images(resized_train_path, 90, lst_imgs_DR)

print("Rotating 120 Degrees")
rotate_images(resized_train_path, 120, lst_imgs_DR)

print("Rotating 180 Degrees")
rotate_images(resized_train_path, 180, lst_imgs_DR)

print("Rotating 270 Degrees")
rotate_images(resized_train_path, 270, lst_imgs_DR)

print("Mirroring DR Images")
mirror_images(resized_train_path, 0, lst_imgs_DR)

print("Completed")
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Mirroring Non-DR Images
# Rotating 90 Degrees
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/204_right_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/766_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/3829_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/3992_right_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/4824_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/5047_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/7466_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/7831_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/8215_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/9205_right_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/9353_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/10651_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/11648_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/12329_right_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/13933_right_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/14915_right_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/15038_right_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/15222_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/16025_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/18972_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/19811_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/19878_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/20009_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/20009_right_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/20824_right_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/21149_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/21447_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/22026_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/23325_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/23369_right_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/23745_right_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/29346_right_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/30606_right_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/31945_right_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/32253_right_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/37813_right_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/38373_right_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/42832_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/43457_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/43921_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/44100_left_90.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# Rotating 120 Degrees
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/204_right_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/766_left_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/3570_right_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/3829_left_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/3992_right_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/4824_left_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/5047_left_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/7466_left_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/8215_left_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/9590_right_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/12329_right_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/13933_right_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/14915_right_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/15222_left_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/18972_left_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/19878_left_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/20009_left_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/20009_right_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/20824_right_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/21720_left_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/23745_right_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/30606_right_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/32253_right_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/39530_left_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/43457_left_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/43921_left_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/44100_left_120.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# Rotating 180 Degrees
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/204_right_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/766_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/3829_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/3992_right_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/4824_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/5047_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/7466_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/7831_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/8215_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/9205_right_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/9353_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/10651_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/11648_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/12329_right_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/13933_right_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/14915_right_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/15038_right_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/15222_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/16025_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/18972_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/19811_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/19878_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/20009_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/20009_right_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/20824_right_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/21149_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/21447_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/22026_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/23325_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/23369_right_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/23745_right_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/29346_right_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/30606_right_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/31945_right_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/32253_right_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/37813_right_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/38373_right_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/42832_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/43457_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/43921_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/44100_left_180.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# Rotating 270 Degrees
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/204_right_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/766_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/3829_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/3992_right_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/4824_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/5047_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/7466_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/7831_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/8215_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/9205_right_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/9353_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/10651_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/11648_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/12329_right_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/13933_right_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/14915_right_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/15038_right_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/15222_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/16025_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/18972_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/19811_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/19878_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/20009_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/20009_right_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/20824_right_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/21149_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/21447_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/22026_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/23325_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/23369_right_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/23745_right_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/29346_right_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/30606_right_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/31945_right_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/32253_right_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/37813_right_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/38373_right_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/42832_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/43457_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/43921_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/master/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../../data/diabetic-retinopathy/train-resized-256/44100_left_270.jpeg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# Mirroring DR Images
# Completed
# --- 444.60251545906067 seconds ---
